# %% [markdown]
# <a href="https://colab.research.google.com/github/Dembelinho/Algo_Genetique_Java_SMA/blob/master/sklearn_Linear_Regression_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("iris_train.csv")
train.head()
# Out:
#    Unnamed: 0  petal_length  petal_width
# 0          22           1.0          0.2
# 1          15           1.5          0.4
# 2          65           4.4          1.4
# 3          11           1.6          0.2
# 4          42           1.3          0.2

# %%
test = pd.read_csv("iris_test.csv")
test.head()
# Out:
#    Unnamed: 0  petal_length  petal_width
# 0          73           4.7          1.2
# 1          18           1.7          0.3
# 2         118           6.9          2.3
# 3          78           4.5          1.5
# 4          76           4.8          1.4

# %%
x_train = train['petal_length'].values
y_train = train['petal_width'].values
x_test = test['petal_length'].values
y_test = test['petal_width'].values

# %%
plt.plot(x_train, y_train, 'o')
plt.title('X_train')
plt.xlabel('Longeur')
plt.ylabel('Largeur')
plt.show()

# %%
plt.plot(x_test, y_test, 'o')
plt.title('X_validation')
plt.xlabel('Longeur')
plt.ylabel('Largeur')
plt.show()

# %%
X = x_train.reshape(-1, 1)
y = y_train.reshape(-1, 1)

modele = linear_model.LinearRegression()
modele.fit(X, y)

X_test = x_test.reshape(-1, 1)
y_test_pred = modele.predict(X_test)

# %%
plt.plot(y_test, label='y_test')
plt.plot(y_test_pred, label='y_tes_pred')
plt.xlabel('Exemples')
plt.ylabel('Largeur')
plt.legend()
plt.show()

# %%
plt.plot(x_test, y_test, 'o', label='test')
plt.plot(x_test, y_test_pred, label='Prédictions')
plt.xlabel('Longeur')
plt.ylabel('Largeur')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse_test = mean_squared_error(y_test, y_test_pred)
mse_test
# Out:
# 0.04557819994873106

# %%
from math import sqrt
sqrt(mse_test)
# Out:
# 0.21349051489171844

# %%
r2_test = r2_score(y_test, y_test_pred)
r2_test
# Out:
# 0.9282973309202085

# %%
y_train_pred = modele.predict(X)

mse_train = mean_squared_error(y_train, y_train_pred)
print("MSE train", mse_train)
print("MSE test", mse_test)
print("RMSE train", sqrt(mse_train))
print("RMSE test", sqrt(mse_test))
# Out:
# MSE train 0.04150255793397939
# MSE test 0.04557819994873106
# RMSE train 0.20372176597992514
# RMSE test 0.21349051489171844

# %%
y_train_pred
# Out:
# array([[0.053131  ],
#        [0.26016473],
#        [1.46096037],
#        [0.30157148],
#        [0.17735124],
#        [1.70940084],
#        [1.50236711],
#        [0.26016473],
#        [0.21875798],
#        [0.26016473],
#        [1.75080759],
#        [1.50236711],
#        [1.58518061],
#        [0.17735124],
#        [0.26016473],
#        [1.17111314],
#        [1.75080759],
#        [1.91643457],
#        [1.46096037],
#        [2.16487505],
#        [1.37814688],
#        [2.37190878],
#        [1.50236711],
#        [0.21875798],
#        [2.41331553],
#        [1.33674013],
#        [0.21875798],
#        [0.17735124],
#        [0.42579172],
#        [1.08829965],
#        [1.6679941 ],
#        [0.42579172],
#        [0.30157148],
#        [0.34297822],
#        [1.37814688],
#        [0.26016473],
#        [1.37814688],
#        [2.41331553],
#        [0.21875798],
#        [1.41955362],
#        [1.70940084],
#        [0.21875798],
#        [1.62658735],
#        [1.75080759],
#        [1.29533338],
#        [1.50236711],
#        [1.87502783],
#        [1.29533338],
#        [0.34297822],
#        [1.00548616],
#        [1.83362108],
#        [0.21875798],
#        [0.13594449],
#        [1.21251989],
#        [1.70940084],
#        [0.26016473],
#        [1.75080759],
#        [0.26016473],
#        [0.30157148],
#        [1.62658735],
#        [0.88126592],
#        [1.99924807],
#        [1.75080759],
#        [1.95784132],
#        [2.16487505],
#        [1.29533338],
#        [0.21875798],
#        [0.09453775],
#        [1.70940084],
#        [2.12346831],
#        [0.26016473],
#        [0.21875798],
#        [0.17735124],
#        [1.6679941 ],
#        [1.95784132],
#        [0.21875798],
#        [1.91643457],
#        [2.12346831],
#        [0.17735124],
#        [1.58518061],
#        [1.54377386],
#        [1.62658735],
#        [1.58518061],
#        [1.83362108],
#        [0.30157148],
#        [1.87502783],
#        [1.37814688],
#        [1.79221434],
#        [1.08829965],
#        [1.25392664],
#        [1.54377386],
#        [0.17735124],
#        [1.54377386],
#        [1.46096037],
#        [0.26016473],
#        [1.33674013],
#        [2.24768854],
#        [1.99924807],
#        [0.26016473],
#        [1.00548616],
#        [1.99924807],
#        [2.04065481],
#        [0.26016473],
#        [1.95784132],
#        [0.21875798],
#        [1.6679941 ],
#        [2.16487505],
#        [1.95784132],
#        [1.33674013],
#        [1.91643457],
#        [1.46096037],
#        [1.41955362],
#        [1.6679941 ],
#        [1.75080759],
#        [0.34297822],
#        [1.29533338],
#        [1.50236711],
#        [0.13594449],
#        [1.29533338],
#        [2.08206156]])
